# %%
import numpy as np
import tensorflow.keras as keras
from tensorflow.keras.initializers import Zeros
import sklearn.datasets as datasets
import pickle

# %%
CENTERS = [[0, 0]]
DATA, _ = datasets.make_blobs(
        n_samples=200,
        centers=CENTERS,
        cluster_std=1,
        random_state=1
    )

cw1 = -1 
cw2 = 1
cb = -1

sw1 = -1
sw2 = 1
sb = 1

X = np.array(list(filter(lambda x : cw1 * x[0] + cw2 * x[1] + cb < -.5 or cw1 * x[0] + cw2 * x[1] + cb > .5, DATA)))
X = np.array(list(filter(lambda x : sw1 * x[0] + sw2 * x[1] + sb < -.5 or sw1 * x[0] + sw2 * x[1] + sb > .5, X)))
C = np.array([0 if cw1 * x[0] + cw2 * x[1] + cb >= 0 else 1 for x in X])
S = np.array([0 if sw1 * x[0] + sw2 * x[1] + sb >= 0 else 1 for x in X])
pass_fail = C ^ S

# %%
# Build the model using Input layer
inputs = keras.layers.Input(shape=(2,))
hidden = keras.layers.Dense(3, activation="sigmoid")(inputs)  # Hidden layer with 3D output
outputs = keras.layers.Dense(1, activation="sigmoid")(hidden)  # Output layer
model = keras.Model(inputs=inputs, outputs=outputs)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-1), loss="binary_crossentropy")
# Prepare storage for hidden space data
hidden_space_trajectory = []
original_points = X  # Store the original points

hidden_layer_model = keras.Model(inputs=model.input, outputs=model.layers[1].output)
# Out:
# 2025-03-16 19:04:32.833727: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2025-03-16 19:04:32.833960: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-03-16 19:04:32.833977: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742166272.834514   62952 pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# I0000 00:00:1742166272.835089   62952 pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Train the model for all epochs and record the hidden space every 10 epochs
epochs_per_interval = 10
total_epochs = 100
hidden_space_trajectory = []

for epoch in range(1, total_epochs + 1):
    # Train for one epoch at a time to monitor progress
    model.fit(X, pass_fail, epochs=1, verbose=1)

    # Record the hidden space trajectory every 10 epochs
    if epoch % epochs_per_interval == 0:
        # Inspect weights
        weights = model.layers[1].get_weights()[0]  # Weights of the hidden layer
        print(f"Weights after {epoch} epochs:\n{weights}")
        hidden_positions = hidden_layer_model.predict(X)
        hidden_space_trajectory.append(hidden_positions)
        print(f"Recorded hidden space at epoch {epoch}")

# Convert hidden_space_trajectory to numpy array for storage
hidden_space_trajectory = np.array(hidden_space_trajectory)
print(f"Hidden space trajectory shape: {hidden_space_trajectory.shape}")
# Out:
# 2025-03-16 19:04:36.413755: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.7215
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7009
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6848
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6763
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6689
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6482
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6272
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5957
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5518
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4931
# Weights after 10 epochs:
# [[-2.0942     -1.2901262  -2.5286782 ]
#  [ 2.6166556  -0.49595812  2.6709812 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Recorded hidden space at epoch 10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4436
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3897
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3453
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2908
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2528
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2284
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2044
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1694
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1559
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1360
# Weights after 20 epochs:
# [[-4.1298447  -0.8074898  -5.1137896 ]
#  [ 4.4648166  -0.15427718  5.0706196 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Recorded hidden space at epoch 20
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1257
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0998
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0896
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0809
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0743
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0675
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0608
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0551
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0500
# Weights after 30 epochs:
# [[-4.8221297  2.3850546 -5.7922864]
#  [ 5.069215  -2.0011613  5.7101874]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 30
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0459
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0410
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0378
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0351
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0324
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0304
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0286
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0268
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0252
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0240
# Weights after 40 epochs:
# [[-5.1957273  3.735129  -6.026147 ]
#  [ 5.3846517 -3.6407852  5.9543285]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 40
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0230
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0214
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0193
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0189
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0179
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0167
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0161
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0155
# Weights after 50 epochs:
# [[-5.3922153  4.3951325 -6.1427975]
#  [ 5.584977  -4.2805586  6.062219 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Recorded hidden space at epoch 50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0153
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0146
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0140
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0136
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0130
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0125
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0120
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0116
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0112
# Weights after 60 epochs:
# [[-5.537063   4.765585  -6.22666  ]
#  [ 5.7407794 -4.6237154  6.1377664]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 60
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0107
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0102
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0098
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0095
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0093
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0086
# Weights after 70 epochs:
# [[-5.655128   5.0226507 -6.291471 ]
#  [ 5.846082  -4.8996487  6.215984 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 70
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0086
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0083
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0081
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0079
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0075
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0074
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0074
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0072
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0070
# Weights after 80 epochs:
# [[-5.762322   5.224688  -6.34696  ]
#  [ 5.932546  -5.0807934  6.268898 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 80
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0069
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0066
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0064
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0063
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0061
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0060
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0058
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0057
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0056
# Weights after 90 epochs:
# [[-5.8454065  5.395023  -6.396244 ]
#  [ 6.014703  -5.238112   6.3167033]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Recorded hidden space at epoch 90
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0058
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0057
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0055
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0054
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0050
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0049
# Weights after 100 epochs:
# [[-5.9234715  5.539686  -6.4407387]
#  [ 6.099359  -5.3869443  6.366542 ]]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Recorded hidden space at epoch 100
# Hidden space trajectory shape: (10, 115, 3)

# %%
# Save the trajectory and original points to a pickle file
with open("hidden_space_and_points.pkl", "wb") as f:
    pickle.dump({"hidden_space_trajectory": hidden_space_trajectory, "original_points": original_points}, f)

print(f"Hidden space trajectory saved with shape: {hidden_space_trajectory.shape}")
print(f"Original points saved with shape: {original_points.shape}")
# Out:
# Hidden space trajectory saved with shape: (10, 115, 3)
# Original points saved with shape: (115, 2)
